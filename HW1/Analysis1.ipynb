# %% [markdown]
# <a href="https://colab.research.google.com/github/justleein2/MachineLearning/blob/main/HW1/Analysis1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Analysis for HW1**
#
# 1. The key steps between managing files between Colab and GitHub starts with making sure both systems are logged into and connected. After you are connected, when you click file and then save a copy to github, edit the front of the name to include your desired folder for its upload.
#
# 2. All of the Module 0 files executed in Colab without editing.
#
# 3. Using the GitHub Web, I clicked Create New Repository. I named the repository Machine Learning and made it public for easy access. After that, I created a new file, named it HW1 and added a readme to make a new folder. Afterwards, I synced my GitHub Desktop to my account and I can open the repository in VS Code from there if I want to.
#
# 4. Python is a useful object oriented programming language that is more flexible and easy to manipulate data sets. There are importable libraries that can help visualize different methods. Machine Learning is easier to comprehend when given a coding language to actually execute the processes.
