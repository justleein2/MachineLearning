# %% [markdown]
# <a href="https://colab.research.google.com/github/justleein2/MachineLearning/blob/main/HW2/HW2Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. I have to upload the file to the Colab each time since I started the assignment on my laptop and then later on my desktop. The datasets are also not presorted and have to be filtered via data type before manipulating it.
#
# 2. I separated the data types by numerical and categorical before imputing it with a median strategy and most frequent for categorical.
#
# 3. To prevent data leakage, we create a Pipeline model using the imputed data. The train and test data is then separated before using it to create graphs.
#
# 4. Based on the heatgraph we can see that the strongest correlation is from failed logins, login attempts and detected attacks. This correlation makes sense because failed attempts are flagged by most security teams.
