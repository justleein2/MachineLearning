# %% [markdown]
# <a href="https://colab.research.google.com/github/justleein2/MachineLearning/blob/main/HW3/analysis3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. When dealing with prepackaged datasets, every value has a predetermined data type. It already considered what should return null or be dropped. Raw external datasets are unfiltered since everything stored is considered a string. The empty values are not dropped and must be manually removed.
#
# 2. I dropped the CustomerID since there would be no correlation to the target churn. Afterwards, I sorted it by numerical and categorical features. This allows me to fill the missing values with 0 if needed for numeric features. Categorical features are imputed using most frequent which would avoid the missing values as well.
#
# 3. ColumnTransformer and Pipeline allows you to separate the numeric and categorical features, train the models separately before merging the data for interpretation later. This can help prevent data leakage since you can handle data with different strategies to better fit the type of data in consideration.
#
# 4. StandardScaler uses standard deviation to center the data around a focal point. By doing this, you can see how different data skews the graph and the influences. While MinMaxScaler sets a fixed range but can be easily affected by outliers. Consequently, StandardScaler is typically more stable for convergence and training.
#
# 5. SGDClassifier(loss="log_loss") takes small data pools and computes the gradient. This is better for larger scaling models. ROC-AUC helps validate the model's quality without relying on a certain threshhold or sample size.
#
# 6. The features with the strongest relationship were internet service fiber optics and contract month to month. This makes sense because customers are able to leave at any time after their month of payment. The non-commitment nature of payment means there will be a high churn rate. The internet service fiber optics is usually a premium service. Customers that are unsatisfied or want to downgrade service will cause a high churn rate as well.
